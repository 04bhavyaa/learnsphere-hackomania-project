# %%
pwd
# Out:
# 'c:\\Users\\bhavy\\Desktop\\backend\\notebook'

# %%
cd ../
# Out:
# c:\Users\bhavy\Desktop\backend
# c:\Users\bhavy\Desktop\backend\learnsphere\Lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
pwd
# Out:
# 'c:\\Users\\bhavy\\Desktop\\backend'

# %%
import pandas as pd
data = pd.read_csv('data/cleaned/student-final.csv')

# %%
data.head()
# Out:
#    gender  mother_job  father_job  internet  freetime  absences  G1  G2  G3  \
# 0       0           0           4         0         3         5   2   8   8
# 1       0           0           2         1         3         3   7   8   8
# 2       0           0           2         1         3         8  10  10  11
# 3       0           1           3         1         2         1  14  14  14
# 4       0           2           2         0         3         2   8  12  12
#
#    school_support  family_support  extra_paid_class  extracurricular  \
# 0               1               0                 0                0
# 1               0               1                 0                0
# 2               1               0                 1                0
# 3               0               1                 1                1
# 4               0               1                 1                0
#
#    higher_edu  romantic_rel
# 0           1             0
# 1           1             0
# ...

# %%
# Correlation Matrix
import seaborn as sns
import matplotlib.pyplot as plt

corr = data.corr()
plt.figure(figsize=(10, 10))
sns.heatmap(corr, annot=True, fmt=".2f")
plt.show()

# %%
data["higher_edu"].value_counts()
# Out:
# higher_edu
# 1    364
# 0     18
# Name: count, dtype: int64
